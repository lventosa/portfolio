# %% [markdown]
# # Who Painted What? Artist Identification Model

# %% [markdown]
# This project has two differentiated parts. Firstly, it explores a dataset with information about famous artists and their paintings. Secondly, a model is built to be able to identify the name of the author given a painting. EXPLICAR MILLOR

# %% [markdown]
# TABLE OF CONTENTS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
artists = pd.read_csv('../art-history/datasets_130081_310927_artists.csv')
artists
# Out:
#     id                       name        years  \
# 0    0          Amedeo Modigliani  1884 - 1920
# 1    1         Vasiliy Kandinskiy  1866 - 1944
# 2    2               Diego Rivera  1886 - 1957
# 3    3               Claude Monet  1840 - 1926
# 4    4              Rene Magritte  1898 - 1967
# 5    5              Salvador Dali  1904 - 1989
# 6    6              Edouard Manet  1832 - 1883
# 7    7              Andrei Rublev  1360 - 1430
# 8    8           Vincent van Gogh  1853 – 1890
# 9    9               Gustav Klimt  1862 - 1918
# 10  10           Hieronymus Bosch  1450 - 1516
# 11  11           Kazimir Malevich  1879 - 1935
# 12  12             Mikhail Vrubel  1856 - 1910
# 13  13              Pablo Picasso  1881 - 1973
# 14  14          Peter Paul Rubens  1577 - 1640
# 15  15      Pierre-Auguste Renoir  1841 - 1919
# 16  16             Francisco Goya  1746 - 1828
# 17  17                Frida Kahlo  1907 - 1954
# 18  18                   El Greco  1541 - 1614
# ...

# %%
artists.shape
# Out:
# (50, 8)

# %%
artists.dtypes
# Out:
# id              int64
# name           object
# years          object
# genre          object
# nationality    object
# bio            object
# wikipedia      object
# paintings       int64
# dtype: object

# %%
genre = artists['genre'].astype('category').cat.categories.tolist()
genre #Pensar com tracto els que són de més d'un gènere
# Out:
# ['Abstract Expressionism',
#  'Baroque',
#  'Byzantine Art',
#  'Cubism',
#  'Early Renaissance',
#  'Expressionism',
#  'Expressionism,Abstractionism',
#  'Expressionism,Abstractionism,Surrealism',
#  'High Renaissance',
#  'High Renaissance,Mannerism',
#  'Impressionism',
#  'Impressionism,Post-Impressionism',
#  'Mannerism',
#  'Neoplasticism',
#  'Northern Renaissance',
#  'Pop Art',
#  'Post-Impressionism',
#  'Primitivism',
#  'Primitivism,Surrealism',
#  'Proto Renaissance',
#  'Realism',
#  'Realism,Impressionism',
#  'Romanticism',
#  'Social Realism,Muralism',
#  'Suprematism',
#  'Surrealism',
#  'Surrealism,Impressionism',
#  'Symbolism',
#  'Symbolism,Art Nouveau',
#  'Symbolism,Expressionism',
#  'Symbolism,Post-Impressionism']

# %%
genre_df = artists.drop(['id', 'name', 'years', 'nationality', 'bio', 'wikipedia'], axis=1)
genre_df1 = genre_df.groupby('genre').count()
genre_df1
genre_df1.columns = ['Counts of each genre']
genre_sorted = genre_df1.sort_values('Counts of each genre', ascending=False)
genre_sorted
# Out:
#                                          Counts of each genre
# genre
# Post-Impressionism                                          4
# Baroque                                                     4
# Northern Renaissance                                        4
# Impressionism                                               4
# High Renaissance                                            3
# Romanticism                                                 3
# Impressionism,Post-Impressionism                            2
# Primitivism                                                 2
# Surrealism                                                  2
# Abstract Expressionism                                      1
# Realism,Impressionism                                       1
# Social Realism,Muralism                                     1
# Proto Renaissance                                           1
# Suprematism                                                 1
# ...

# %%
plt.figure(figsize=(15,10))
artists['genre'].value_counts().plot(kind='bar', color='indianred', title='kjfd');

# %%
sns.set_context('talk')
plt.figure(figsize=(28,35))
barplot = sns.barplot(x='paintings', y='name', data=artists, orient='h', saturation=0.7)
barplot.axes.set_title('Paintings per Artist', fontsize=20, y=1.01)
barplot.set(xlabel='Number of Paintings', ylabel='Artist');

# %% [markdown]
# EXPLICACIÓ

# %%
artists['paintings'].describe()
# Out:
# count     50.000000
# mean     168.920000
# std      157.451105
# min       24.000000
# 25%       81.000000
# 50%      123.000000
# 75%      191.750000
# max      877.000000
# Name: paintings, dtype: float64

# %%
sns.boxplot(y=artists['paintings'], color='bisque');
plt.show()

# %% [markdown]
# EXPLICAR PAINTINGS
